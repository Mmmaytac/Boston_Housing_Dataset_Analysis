# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkST0151ENSkillsNetwork20531532-2022-01-01" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo">
#     </a>
# </p>

# %% [markdown]
# # **Final Project: Boston Housing**

# %% [markdown]
# ##### Estimated time needed: **60** minutes

# %% [markdown]
# #### Import the required libraries we need for the lab.

# %% [markdown]
# # Familiarize Yourself with the Dataset

# %%
import piplite
await piplite.install(['numpy'],['pandas'])
await piplite.install(['seaborn'])

# %%
import pandas as pd
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as pyplot
import scipy.stats
import statsmodels.api as sm
from statsmodels.formula.api import ols
# Out:
# <ipython-input-2-b3fdaf15785b>:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %% [markdown]
# #### Read the dataset in the csv file from the URL

# %%
from js import fetch
import io

URL = 'https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-ST0151EN-SkillsNetwork/labs/boston_housing.csv'
resp = await fetch(URL)
boston_url = io.BytesIO((await resp.arrayBuffer()).to_py())

# %%
boston_df=pd.read_csv(boston_url)

# %% [markdown]
# #### Add your code below following the instructions given in the course to complete the peer graded assignment

# %%
boston_df
# Out:
#      Unnamed: 0     CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  \
# 0             0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0
# 1             1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0
# 2             2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0
# 3             3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0
# 4             4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0
# ..          ...      ...   ...    ...   ...    ...    ...   ...     ...  ...
# 501         501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0
# 502         502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0
# 503         503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0
# 504         504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0
# 505         505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0
#
#        TAX  PTRATIO  LSTAT  MEDV
# ...

# %%
boston_df.head()
# Out:
#    Unnamed: 0     CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  \
# 0           0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0
# 1           1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0
# 2           2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0
# 3           3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0
# 4           4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0
#
#      TAX  PTRATIO  LSTAT  MEDV
# 0  296.0     15.3   4.98  24.0
# 1  242.0     17.8   9.14  21.6
# 2  242.0     17.8   4.03  34.7
# 3  222.0     18.7   2.94  33.4
# 4  222.0     18.7   5.33  36.2

# %%
boston_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  506 non-null    int64
#  1   CRIM        506 non-null    float64
#  2   ZN          506 non-null    float64
#  3   INDUS       506 non-null    float64
#  4   CHAS        506 non-null    float64
#  5   NOX         506 non-null    float64
#  6   RM          506 non-null    float64
#  7   AGE         506 non-null    float64
#  8   DIS         506 non-null    float64
#  9   RAD         506 non-null    float64
#  10  TAX         506 non-null    float64
#  11  PTRATIO     506 non-null    float64
#  12  LSTAT       506 non-null    float64
#  13  MEDV        506 non-null    float64
# dtypes: float64(13), int64(1)
# memory usage: 55.4 KB

# %%
for column in list(boston_df.columns):
    print(f"{column}: {boston_df[column].isnull().sum()}")
# Out:
# Unnamed: 0: 0
# CRIM: 0
# ZN: 0
# INDUS: 0
# CHAS: 0
# NOX: 0
# RM: 0
# AGE: 0
# DIS: 0
# RAD: 0
# TAX: 0
# PTRATIO: 0
# LSTAT: 0
# MEDV: 0

# %%
boston_df.duplicated().sum()
# Out:
# 0

# %%
boston_df.corr()
# Out:
#             Unnamed: 0      CRIM        ZN     INDUS      CHAS       NOX  \
# Unnamed: 0    1.000000  0.407407 -0.103393  0.399439 -0.003759  0.398736
# CRIM          0.407407  1.000000 -0.200469  0.406583 -0.055892  0.420972
# ZN           -0.103393 -0.200469  1.000000 -0.533828 -0.042697 -0.516604
# INDUS         0.399439  0.406583 -0.533828  1.000000  0.062938  0.763651
# CHAS         -0.003759 -0.055892 -0.042697  0.062938  1.000000  0.091203
# NOX           0.398736  0.420972 -0.516604  0.763651  0.091203  1.000000
# RM           -0.079971 -0.219247  0.311991 -0.391676  0.091251 -0.302188
# AGE           0.203784  0.352734 -0.569537  0.644779  0.086518  0.731470
# DIS          -0.302211 -0.379670  0.664408 -0.708027 -0.099176 -0.769230
# RAD           0.686002  0.625505 -0.311948  0.595129 -0.007368  0.611441
# TAX           0.666626  0.582764 -0.314563  0.720760 -0.035587  0.668023
# PTRATIO       0.291074  0.289946 -0.391679  0.383248 -0.121515  0.188933
# ...

# %%
sns.heatmap(boston_df.corr())
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Generate Descriptive Statistics and Visualizations

# %%
boston_df.describe()
# Out:
#        Unnamed: 0        CRIM          ZN       INDUS        CHAS         NOX  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean   252.500000    3.613524   11.363636   11.136779    0.069170    0.554695
# std    146.213884    8.601545   23.322453    6.860353    0.253994    0.115878
# min      0.000000    0.006320    0.000000    0.460000    0.000000    0.385000
# 25%    126.250000    0.082045    0.000000    5.190000    0.000000    0.449000
# 50%    252.500000    0.256510    0.000000    9.690000    0.000000    0.538000
# 75%    378.750000    3.677083   12.500000   18.100000    0.000000    0.624000
# max    505.000000   88.976200  100.000000   27.740000    1.000000    0.871000
#
#                RM         AGE         DIS         RAD         TAX     PTRATIO  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     6.284634   68.574901    3.795043    9.549407  408.237154   18.455534
# ...

# %%
sns.boxplot(boston_df.MEDV)
# Out:
# <AxesSubplot:ylabel='MEDV'>

# %%
sns.countplot(x=boston_df["CHAS"])

pyplot.title("Bar Plot of CHAS (Charles River)")
pyplot.xlabel("Bounded by Charles River")
pyplot.ylabel("Count")
pyplot.show()

# %%
boston_df["age_group"]=pd.cut(boston_df['AGE'],bins=[0,35,70,100], labels=["new","middle","old"])
boston_df["age_group"]
sns.boxplot(x=boston_df["age_group"],y=boston_df["MEDV"])
pyplot.title("MEDV vs AGE Groups")
pyplot.xlabel("Age Group")
pyplot.ylabel("Median Home Value")
pyplot.show()

# %%
sns.scatterplot(x=boston_df.NOX, y=boston_df.INDUS)
pyplot.show()

# %%
sns.histplot(boston_df.PTRATIO)
# Out:
# <AxesSubplot:xlabel='PTRATIO', ylabel='Count'>

# %% [markdown]
# # Apply Statistical Tests

# %%
from scipy.stats import levene

chas1 = boston_df[boston_df["CHAS"] == 1]["MEDV"]
chas0 = boston_df[boston_df["CHAS"] == 0]["MEDV"]

stat, p = levene(chas1, chas0)

print("Levene Statistic:", stat)
print("p-value:", p)
# Out:
# Levene Statistic: 4.590342218715871
# p-value: 0.03263097600633006

# %% [raw]
# The Levene's Test result produced a p-value of 0.0326, which is less than the significance level of 0.05. Therefore, we reject the null hypothesis that the variances of MEDV are equal between homes bounded by the Charles River (CHAS = 1) and those not bounded (CHAS = 0).
#
# This indicates that there is a statistically significant difference in the variances of median home values between the two groups in the Boston Housing Dataset. In other words, the variability in housing prices differs depending on whether the homes are located near the Charles River or not.

# %%
from scipy.stats import ttest_ind

chas1 = boston_df[boston_df["CHAS"] == 1]["MEDV"]
chas0 = boston_df[boston_df["CHAS"] == 0]["MEDV"]

stat, p = ttest_ind(chas1, chas0, equal_var=False)

print("T-test Statistic:", stat)
print("p-value:", p)
# Out:
# T-test Statistic: 3.113291312794837
# p-value: 0.003567170098137517

# %% [raw]
# The two-sample t-test comparing MEDV for homes bounded by the Charles River (CHAS = 1) and those not bounded (CHAS = 0) produced a t-statistic of 3.11 with a p-value of 0.00357, which is less than 0.05.
#
# This means we reject the null hypothesis and conclude that there is a statistically significant difference in median home values between homes near the Charles River and those farther away.
# In other words, homes located near the Charles River tend to have different (likely higher) median values compared to homes not near the river.

# %%
from scipy.stats import f_oneway

new_group = boston_df[boston_df["age_group"] == "new"]["MEDV"]
middle_group = boston_df[boston_df["age_group"] == "middle"]["MEDV"]
old_group = boston_df[boston_df["age_group"] == "old"]["MEDV"]

stat, p = f_oneway(new_group, middle_group, old_group)

print("ANOVA Statistic:", stat)
print("p-value:", p)
# Out:
# ANOVA Statistic: 36.40764999196599
# p-value: 1.7105011022702984e-15

# %% [raw]
# The one-way ANOVA comparing MEDV across the three AGE groups (“New”, “Middle”, “Old”) produced an F-statistic of 36.41 with a p-value of 1.71 × 10⁻¹⁵, which is far below the 0.05 significance level.
#
# This means we reject the null hypothesis and conclude that there is a statistically significant difference in median home values among the three AGE groups.
# In other words, the age of homes strongly affects their median value, and at least one AGE group has a median home value significantly different from the others.

# %%
from scipy.stats import pearsonr

nox = boston_df["NOX"]
indus = boston_df["INDUS"]

r, p = pearsonr(nox, indus)

print("Pearson correlation coefficient:", r)
print("p-value:", p)
# Out:
# Pearson correlation coefficient: 0.7636514469209192
# p-value: 7.913361061210442e-98

# %% [raw]
# The Pearson correlation test between NOX (Nitric Oxide concentration) and INDUS (proportion of non-retail business acres per town) produced a correlation coefficient of 0.764 with a p-value of 7.91 × 10⁻⁹⁸, which is far below 0.05.
#
# This indicates a strong and statistically significant positive correlation between NOX and INDUS.
# In other words, towns with a higher proportion of non-retail business acres tend to have higher Nitric Oxide concentrations, suggesting that industrial areas contribute substantially to air pollution.

# %%
import statsmodels.api as sm

X = boston_df["DIS"]
y = boston_df["MEDV"]

X = sm.add_constant(X)

model = sm.OLS(y, X).fit()

print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                   MEDV   R-squared:                       0.062
# Model:                            OLS   Adj. R-squared:                  0.061
# Method:                 Least Squares   F-statistic:                     33.58
# Date:                Mon, 16 Mar 2026   Prob (F-statistic):           1.21e-08
# Time:                        16:47:49   Log-Likelihood:                -1823.9
# No. Observations:                 506   AIC:                             3652.
# Df Residuals:                     504   BIC:                             3660.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         18.3901      0.817     22.499      0.000      16.784      19.996
# ...

# %% [raw]
# A simple linear regression was performed to evaluate the impact of DIS (distance to Boston employment centres) on MEDV (median home value). The regression results show a positive coefficient of 1.09 (p < 0.001) for DIS, indicating that for each additional unit of distance from the employment centres, the median home value increases by approximately $1,092.
#
# Although the effect is statistically significant, the **R-squared is 0.062**, meaning that the distance variable explains only about 6.2% of the variation in home values. This suggests that while homes farther from employment centres tend to have slightly higher median values, there are likely many other factors influencing housing prices.
#
# Key takeaway: Homes located farther from Boston’s employment centres tend to have higher median values, but distance alone does not strongly predict overall home prices.
